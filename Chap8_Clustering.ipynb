# %% [markdown]
# <a href="https://colab.research.google.com/github/Chanakarn06/DWDM21/blob/main/Chap8_Clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Generate Data**

# %%
from sklearn.datasets import make_blobs

# %%
X,y = make_blobs(n_samples=500,centers=3,n_features=2,random_state=6)

# %%
X.shape
# Out:
# (500, 2)

# %%
from matplotlib import pyplot as plt
plt.scatter(X[:,0],X[:,1])

# %% [markdown]
# **import**

# %%
from sklearn.cluster import  KMeans

# %% [markdown]
# **Define**

# %%
kmeans = KMeans(n_clusters=2 , random_state=6)

# %% [markdown]
# **Train-Peadict**

# %%
y_clust = kmeans.fit_predict(X)

# %%
plt.scatter(X[:,0],X[:,1],c=y_clust)

# %% [markdown]
# 4 clusters

# %%
#Define
kmeans = KMeans(n_clusters=2 , random_state=6)
#Fit-Peadict
y_clust = kmeans.fit_predict(X)
#plot
plt.scatter(X[:,0],X[:,1],c=y_clust)

# %%
#Define
kmeans = KMeans(n_clusters=5 , random_state=6 , init = 'random')
#Fit-Peadict
y_clust = kmeans.fit_predict(X)
#plot
plt.scatter(X[:,0],X[:,1],c=y_clust)

# %% [markdown]
# Example Application Color quantization

# %%
import cv2
import os

# %%
img = cv2.imread('/content/_119932207_indifferentcatgettyimages.png')

# %%
img.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-98-32ad6cb7aa56> in <module>()
# ----> 1 img.shape
#
# AttributeError: 'NoneType' object has no attribute 'shape'
