# %% [markdown]
# <a href="https://colab.research.google.com/github/Chanakarn06/DWDM21/blob/main/Basic_Programming_Concepts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Functions ($f(x) = y$)

# %% [markdown]
# ```python
# def function_name(input_x):
#     # do something with input_x to get output_y
#     return output_y
# ```

# %% [markdown]
# $f_1(x)=x^2 + 75$

# %%
def function_f1(x):
    a = x**2
    y = a + 75
    return y

print('done!')
# Out:
# done!

# %%
function_f1(3)
# Out:
# 84

# %% [markdown]
# function มีส่วนสำคัญทั้งหมด 4 ส่วน
#
# 1. บอก python ว่าเราจะเขียนฟังก์ชั่น ชื่ออะไร  `def function_name()`: (ขาดไม่ได้)
# 2. กำหนดตัวแปรที่จะเป็น input  _Input_ (ขาดได้)
# 3. ส่วนประมวลผล do_something with _Input_ to get _Output_ (ขาดไม่ได้)
# 4. ส่วน output `return` _Output_(ขาดได้)

# %% [markdown]
# ### ตัวอย่าง function ที่มีส่วนประกอบครบ

# %%
def function_f1(x):
    a = x**2
    y = a + 75
    return y

# %% [markdown]
# ### ตัวอย่าง function ที่ ไม่มี input

# %%
def pi_v():
    y = 3.14159265359
    return y

# %%
piv = pi_v()
circle_area_r2 = piv*(2**2)
print(circle_area_r2)
# Out:
# 12.56637061436

# %% [markdown]
# ### Function ไม่มี process ไม่ได้

# %%
def function_a():
# Out:
#   File "<ipython-input-9-07a0750214a8>", line 1
#     def function_a():
#                      ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# ตัวอย่าง Function ที่ไม่มี output

# %%
def print_name_id(name,id):
    print(f'ชื่อ {name} รหัสประจำตัว {id}')

# %%
print_name_id('ชนกานต์','623021046-7')
# Out:
# ชื่อ ชนกานต์ รหัสประจำตัว 623021046-7

# %%
a = print_name_id('ชนกานต์','623021046-7')
# Out:
# ชื่อ ชนกานต์ รหัสประจำตัว 623021046-7

# %%
a

# %% [markdown]
# ตัวอย่าง function `print` https://www.programiz.com/python-programming/methods/built-in/print
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
print('ชนกานต์')
print('623021046-7')
# Out:
# ชนกานต์
# 623021046-7

# %%
print('ชนกานต์',end='->')
print('623021046-7')
# Out:
# ชนกานต์->623021046-7

# %%
print('ชนกานต์','623021046-7')
# Out:
# ชนกานต์ 623021046-7

# %%
print('ชนกานต์','623021046-7',sep=' & ')
# Out:
# ชนกานต์ & 623021046-7

# %% [markdown]
# ## input ของ function แบ่งเป็น 2 ชนิด (จำเป็นต้องใส่ กับ ไม่จำเป็นต้องใส่)

# %% [markdown]
# ตัวอย่าง function `print_grade()` มี input 3 ตัว จำเป็นต้องใส่ 2 ตัว คือ name กับ id และไม่จำเป็นต้องใส่ 1 ตัว คือเกรด ซึ่งมีค่า default เป็น F

# %%
def print_grade(name,id,grade = 'A'):
    print(f'รหัสประจำตัว {id} ชื่อ {name}')
    print(f'ได้เกรด {grade}')

# %%
print_grade('นางสาวชนกานต์ พูลผล','623021046-7')
# Out:
# รหัสประจำตัว 623021046-7 ชื่อ นางสาวชนกานต์ พูลผล
# ได้เกรด A

# %%
print_grade('นางสาวชนกานต์ พูลผล','623021046-7','B')
# Out:
# รหัสประจำตัว 623021046-7 ชื่อ นางสาวชนกานต์ พูลผล
# ได้เกรด B

# %%
print_grade(id='623021046-7',name='นางสาวชนกานต์ พูลผล',grade='B+')
# Out:
# รหัสประจำตัว 623021046-7 ชื่อ นางสาวชนกานต์ พูลผล
# ได้เกรด B+

# %% [markdown]
# # Looping (for)

# %% [markdown]
# # Conditional Statement (if)
