# %% [markdown]
# <a href="https://colab.research.google.com/github/Chanakarn06/DWDM21/blob/main/Data_Preprocessing(Chapter_3).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd # ทำงานกับข้อมูลลักษณะ ตาราง

# %%
from google.colab import drive # เชื่อม google drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os # จัดการไฟล์และ path

# %%
path = '/content/drive/My Drive/DWDM2021_DATA'

# %%
data_cases = pd.read_csv(os.path.join(path,'confirmed-cases (5).csv'))
data_cases
# Out:
#              No. announce_date  ... province_of_onset district_of_onset
# 0            1.0     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1            2.0     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3.0     22/1/2020  ...            นครปฐม             เมือง
# 3            4.0     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5.0     24/1/2020  ...     กรุงเทพมหานคร               NaN
# ...          ...           ...  ...               ...               ...
# 543301  543302.0     28/7/2021  ...        สุพรรณบุรี               NaN
# 543302  543303.0     28/7/2021  ...        สุพรรณบุรี               NaN
# 543303  543304.0     28/7/2021  ...        สุพรรณบุรี               NaN
# 543304  543305.0     28/7/2021  ...           ปัตตานี               NaN
# 543305       NaN           NaN  ...               NaN               NaN
#
# [543306 rows x 11 columns]

# %% [markdown]
# Meta Data (Data ที่ใช้อธิบาย Data)

# %% [markdown]
# ชี้ข้อมูลในตาราง

# %% [markdown]
# # ชี้แบบธรรมดา ใช้ [ชื่ออ column][index]

# %%
data_cases['risk']
# Out:
# 0         คนต่างชาติเดินทางมาจากต่างประเทศ
# 1         คนต่างชาติเดินทางมาจากต่างประเทศ
# 2         คนต่างชาติเดินทางมาจากต่างประเทศ
# 3         คนต่างชาติเดินทางมาจากต่างประเทศ
# 4         คนต่างชาติเดินทางมาจากต่างประเทศ
#                         ...
# 543301                    ทัณฑสถาน/เรือนจำ
# 543302                    ทัณฑสถาน/เรือนจำ
# 543303                    ทัณฑสถาน/เรือนจำ
# 543304                    ทัณฑสถาน/เรือนจำ
# 543305                                 NaN
# Name: risk, Length: 543306, dtype: object

# %%
data_cases['risk'][678]
# Out:
# 'สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้'

# %%
data_cases[['age','risk','sex']]
# Out:
#          age                              risk   sex
# 0       61.0  คนต่างชาติเดินทางมาจากต่างประเทศ  หญิง
# 1       74.0  คนต่างชาติเดินทางมาจากต่างประเทศ  หญิง
# 2       73.0  คนต่างชาติเดินทางมาจากต่างประเทศ  หญิง
# 3       68.0  คนต่างชาติเดินทางมาจากต่างประเทศ   ชาย
# 4       66.0  คนต่างชาติเดินทางมาจากต่างประเทศ  หญิง
# ...      ...                               ...   ...
# 543301  39.0                  ทัณฑสถาน/เรือนจำ   ชาย
# 543302  37.0                  ทัณฑสถาน/เรือนจำ   ชาย
# 543303  28.0                  ทัณฑสถาน/เรือนจำ   ชาย
# 543304  26.0                  ทัณฑสถาน/เรือนจำ   ชาย
# 543305   NaN                               NaN   NaN
#
# [543306 rows x 3 columns]

# %% [markdown]
# ชี้แบบ .iloc[] (มองข้อมูลเป็น matrix)

# %%
data_cases.iloc[678,8]
# Out:
# 'สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้'

# %%
data_cases.iloc[-10:,4:9:2]
# Out:
#          age nationality              risk
# 543296  47.0         NaN  ทัณฑสถาน/เรือนจำ
# 543297  38.0         NaN  ทัณฑสถาน/เรือนจำ
# 543298  39.0         NaN  ทัณฑสถาน/เรือนจำ
# 543299  40.0         NaN  ทัณฑสถาน/เรือนจำ
# 543300  38.0         NaN  ทัณฑสถาน/เรือนจำ
# 543301  39.0         NaN  ทัณฑสถาน/เรือนจำ
# 543302  37.0         NaN  ทัณฑสถาน/เรือนจำ
# 543303  28.0         NaN  ทัณฑสถาน/เรือนจำ
# 543304  26.0         NaN  ทัณฑสถาน/เรือนจำ
# 543305   NaN         NaN               NaN

# %%
data_cases.iloc[-10:,[3,4,8]]
# Out:
#         sex   age              risk
# 543296  ชาย  47.0  ทัณฑสถาน/เรือนจำ
# 543297  ชาย  38.0  ทัณฑสถาน/เรือนจำ
# 543298  ชาย  39.0  ทัณฑสถาน/เรือนจำ
# 543299  ชาย  40.0  ทัณฑสถาน/เรือนจำ
# 543300  ชาย  38.0  ทัณฑสถาน/เรือนจำ
# 543301  ชาย  39.0  ทัณฑสถาน/เรือนจำ
# 543302  ชาย  37.0  ทัณฑสถาน/เรือนจำ
# 543303  ชาย  28.0  ทัณฑสถาน/เรือนจำ
# 543304  ชาย  26.0  ทัณฑสถาน/เรือนจำ
# 543305  NaN   NaN               NaN

# %%
data_cases.describe()
# Out:
#                  No.            age
# count  543305.000000  491048.000000
# mean   271653.000000      35.519252
# std    156838.788338      16.197363
# min         1.000000       1.000000
# 25%    135827.000000      25.000000
# 50%    271653.000000      34.000000
# 75%    407479.000000      46.000000
# max    543305.000000     108.000000

# %%
from matplotlib import pyplot as plt

plt.boxplot(data_cases['age'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7fd1e83f6710>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fd1e83fe750>,
#   <matplotlib.lines.Line2D at 0x7fd1e83fec90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fd1e8404790>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7fd1e8404250>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fd1e83f6c90>,
#   <matplotlib.lines.Line2D at 0x7fd1e83fe210>]}

# %%
data_cases.iloc[-10,4]
# Out:
# 47.0

# %% [markdown]
# #Missing Values
#
#
#
#
# *   NaN = Not a Number
# *   Null
# * NA = Not Available

# %%
data_cases
# Out:
#              No. announce_date  ... province_of_onset district_of_onset
# 0            1.0     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1            2.0     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3.0     22/1/2020  ...            นครปฐม             เมือง
# 3            4.0     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5.0     24/1/2020  ...     กรุงเทพมหานคร               NaN
# ...          ...           ...  ...               ...               ...
# 543301  543302.0     28/7/2021  ...        สุพรรณบุรี               NaN
# 543302  543303.0     28/7/2021  ...        สุพรรณบุรี               NaN
# 543303  543304.0     28/7/2021  ...        สุพรรณบุรี               NaN
# 543304  543305.0     28/7/2021  ...           ปัตตานี               NaN
# 543305       NaN           NaN  ...               NaN               NaN
#
# [543306 rows x 11 columns]

# %%
data_cases.isnull()
# Out:
#           No.  announce_date  ...  province_of_onset  district_of_onset
# 0       False          False  ...              False               True
# 1       False          False  ...              False               True
# 2       False          False  ...              False              False
# 3       False          False  ...              False               True
# 4       False          False  ...              False               True
# ...       ...            ...  ...                ...                ...
# 543301  False          False  ...              False               True
# 543302  False          False  ...              False               True
# 543303  False          False  ...              False               True
# 543304  False          False  ...              False               True
# 543305   True           True  ...               True               True
#
# [543306 rows x 11 columns]

# %%
data_cases.isnull().any() #สรุปข้อมูลเป็นรายคอลัม
# Out:
# No.                      True
# announce_date            True
# Notified date            True
# sex                      True
# age                      True
# Unit                     True
# nationality              True
# province_of_isolation    True
# risk                     True
# province_of_onset        True
# district_of_onset        True
# dtype: bool

# %% [markdown]
# ### Handlind Missing Value 1 (ลบค่า missing)

# %%
plt.boxplot(data_cases['age'].dropna())
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7fd1e7f4c350>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fd1e7f533d0>,
#   <matplotlib.lines.Line2D at 0x7fd1e7f53910>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fd1e7f5a410>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7fd1e7f53e90>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fd1e7f4c910>,
#   <matplotlib.lines.Line2D at 0x7fd1e7f4ce50>]}

# %%
data_cases.dropna()
# Out:
#              No. announce_date  ... province_of_onset district_of_onset
# 47          48.0      6/3/2020  ...     กรุงเทพมหานคร           คลองตัน
# 124        125.0      6/3/2021  ...          ปทุมธานี           ธัญบุรี
# 161        162.0     17/3/2020  ...      สุราษฎร์ธานี             เมือง
# 181        182.0     18/3/2020  ...           ขอนแก่น             เมือง
# 186        187.0     18/3/2020  ...          ร้อยเอ็ด         เชียงขวัญ
# ...          ...           ...  ...               ...               ...
# 543098  543099.0     28/7/2021  ...            นครปฐม          พุทธมณฑล
# 543099  543100.0     28/7/2021  ...     กรุงเทพมหานคร           หนองแขม
# 543100  543101.0     28/7/2021  ...     กรุงเทพมหานคร             ดุสิต
# 543101  543102.0     28/7/2021  ...     กรุงเทพมหานคร       ราษฎร์บูรณะ
# 543102  543103.0     28/7/2021  ...     กรุงเทพมหานคร            ประเวศ
#
# [385643 rows x 11 columns]

# %%
data_cases.dropna().shape
# Out:
# (385643, 11)

# %%
data_cases.dropna().shape[0]
# Out:
# 385643

# %% [markdown]
# ###Quiz 3 หาว่า การทำ dropna() ทำให้ข้อมูลหายไปกี่ %
#
#
#
#
# ```
# size before drop = 1000
# size after drop = 10
# we loss 99% of data
# ```

# %%
after = data_cases.shape[0] - data_cases.dropna().shape[0]
after
# Out:
# 157663

# %%
data_af = (after/data_cases.shape[0])*100
data_af
# Out:
# 29.019189922437818

# %%
removed = data_cases.shape[0] - data_cases.dropna().shape[0]

print(f'size before drop = {data_cases.shape[0]}')
print(f'size after drop = {data_cases.dropna().shape[0]}')
print(f'we lost {100*(removed/data_cases.shape[0])}% of data')
# Out:
# size before drop = 543306
# size after drop = 385643
# we lost 29.019189922437818% of data

# %% [markdown]
# ### Handling Missing Value 1.5 (ลบค่า Missing เฉพาะใน column ที่เราสนใจ)

# %%
data_cases_nomissingAge = data_cases.dropna(subset=['age'])

# %%
plt.boxplot(data_cases_nomissingAge['age'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7fd1e7450210>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fd1e7456290>,
#   <matplotlib.lines.Line2D at 0x7fd1e74567d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fd1e745e2d0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7fd1e7456d50>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fd1e74507d0>,
#   <matplotlib.lines.Line2D at 0x7fd1e7450d10>]}

# %% [markdown]
# Quiz 3.1 ให้หาว่า การทำ dropna() แบบเลือก drop เฉพาะ column ที่เราสนใจ ทำให้ข้อมูลหายไปกี่ %

# %%
removed = data_cases.shape[0] - data_cases_nomissingAge.shape[0]

print(f'size before drop = {data_cases.shape[0]}')
print(f'size after drop = {data_cases_nomissingAge.shape[0]}')
print(f'we lost {100*(removed/data_cases.shape[0])}% of data')
# Out:
# size before drop = 543306
# size after drop = 491048
# we lost 9.618520686316735% of data

# %% [markdown]
# ### Handling Missing Value 2 (แทนด้วย class ใหม่ (unknown)

# %%
data_cases
# Out:
#              No. announce_date  ... province_of_onset district_of_onset
# 0            1.0     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1            2.0     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3.0     22/1/2020  ...            นครปฐม             เมือง
# 3            4.0     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5.0     24/1/2020  ...     กรุงเทพมหานคร               NaN
# ...          ...           ...  ...               ...               ...
# 543301  543302.0     28/7/2021  ...        สุพรรณบุรี               NaN
# 543302  543303.0     28/7/2021  ...        สุพรรณบุรี               NaN
# 543303  543304.0     28/7/2021  ...        สุพรรณบุรี               NaN
# 543304  543305.0     28/7/2021  ...           ปัตตานี               NaN
# 543305       NaN           NaN  ...               NaN               NaN
#
# [543306 rows x 11 columns]

# %%
data_cases[['risk']] = data_cases[['risk']].fillna('ไม่มีข้อมูล')

# %%
set(data_cases['risk'])
# Out:
# {'2.สัมผัสผู้ติดเชื้อ',
#  'ACF รองเมือง',
#  'ACF สนามกีฬาธูปะเตมีย์',
#  'ACF สนามกีฬาไทย-ญี่ปุ่น',
#  'ACF สีลม',
#  'ACF เคหะหลักสี่',
#  'Cluster Icon siam',
#  "Cluster Memory 90's กรุงเทพมหานคร",
#  'Cluster New Jazz กรุงเทพมหานคร',
#  'Cluster The Lounge Salaya',
#  'Cluster กรุงเทพมหานคร. คลองเตย',
#  'Cluster คลองเตย',
#  'Cluster งานมอเตอร์ โชว์',
#  'Cluster จนท. สนามบินสุวรรณภูมิ',
#  'Cluster จันทบุรี',
#  'Cluster จันทบุรี (ชาวกินี )',
#  'Cluster จันทบุรี (ชาวกินี)',
#  'Cluster ชลบุรี',
#  'Cluster ชลบุรี บริษัทไดกิ้น',
#  'Cluster ชลบุรี โรงเบียร์ 90',
#  'Cluster ตราด',
#  'Cluster ตราด ',
#  'Cluster ตลาดนนทบุรี',
#  'Cluster ตลาดบางพลี',
#  'Cluster ตลาดบางแค',
#  'Cluster ตลาดบางแค/คลองขวาง',
#  'Cluster ตลาดพรพัฒน์',
#  'Cluster ตลาดสี่มุมเมือง',
#  'Cluster ทัณฑสถานหญิงกลาง',
#  'Cluster ทัณฑสถานโรงพยาบาลราชทัณฑ์',
#  'Cluster ทันฑสถานบำบัดพิเศษกลาง',
#  'Cluster บริษัทศรีสวัสดิ์',
#  'Cluster บางแค',
#  'Cluster บ่อนพัทยา/ชลบุรี',
#  'Cluster บ่อนเทพารักษ์',
#  'Cluster บ่อนไก่อ่างทอง',
#  'Cluster ปากช่อง',
#  'Cluster ผับ Thonglor',
#  'Cluster มหาสารคาม',
#  'Cluster ระยอง',
#  'Cluster ระยอง วิริยะประกันภัย',
#  'Cluster สถานบันเทิงย่านทองหล่อ',
#  'Cluster สมุทรปราการ (โรงงาน บริษัทเมทัล โปรดักส์)',
#  'Cluster สมุทรปราการ GRP Hightech',
#  'Cluster สมุทรปราการ ตลาดเคหะบางพลี',
#  'Cluster สมุทรสาคร',
#  'Cluster ห้างแสงทอง (สายล่าง)',
#  'Cluster เครือคัสเซ่อร์พีคโฮลดิ้ง (CPG,CPH)',
#  'Cluster เรือนจำกลางคลองเปรม',
#  'Cluster เรือนจำพิเศษกรุงเทพ',
#  'Cluster เรือนจำพิเศษธนบุรี',
#  'Cluster เรือนจำพิเศษมีนบุรี',
#  'Cluster โรงงาน  Big Star',
#  'Cluster โรงงาน Big Star',
#  'Cluster โรงงาน QPP ประจวบฯ',
#  'Cluster โรงงาน standard can',
#  'Cluster โรงงานทำขนม บางขุนเทียน',
#  'Refer in',
#  'SHUI',
#  'Sandbox',
#  'State Quarantine',
#  'cluster ชลบุรี\n(อยู่ระหว่างการสอบสวน)',
#  'การค้นหาผู้ป่วยเชิงรุกและค้นหาผู้ติดเชื้อในชุมชน',
#  'คนต่างชาติเดินทางมาจากต่างประเทศ',
#  'คนไทยมาจากพื้นที่เสี่ยง',
#  'คนไทยเดินทางกลับจากต่างประเทศ',
#  'คนไทยเดินทางมาจากต่างประเทศ',
#  'ค้นหาเชิงรุก',
#  'ตรวจก่อนทำหัตถการ',
#  'ตรวจสุขภาพแรงงานต่างด้าว',
#  'ตลาด',
#  'ทัณฑสถาน/เรือนจำ',
#  'บุคลากรด้านการแพทย์และสาธารณสุข',
#  'ปอดอักเสบ (Pneumonia)',
#  'ปอดอักเสบ Pneumonia',
#  'ผับหัวหิน',
#  'ผู้ติดเชื้อในประเทศ',
#  'ผู้ที่เดินทางมาจากต่างประเทศ และเข้า AOQ',
#  'ผู้ที่เดินทางมาจากต่างประเทศ และเข้า ASQ/ALQ',
#  'ผู้ที่เดินทางมาจากต่างประเทศ และเข้า HQ/AHQ',
#  'ผู้ที่เดินทางมาจากต่างประเทศ และเข้า OQ',
#  'ผู้ป่วย PUI',
#  'ผู้ป่วย กรุงเทพมหานคร',
#  'ผู้เดินทางมาจากพื้นที่เสี่ยง กรุงเทพมหานคร.',
#  'พิธีกรรมทางศาสนา',
#  'มาจากพื้นที่เสียง จ.ปทุมธานี',
#  'มาจากพื้นที่เสี่ยง',
#  'มาจากพื้นที่เสี่ยง จ.ปทุมธานี',
#  'รอประสาน',
#  'ระบุไม่ได้',
#  'ระหว่างการสอบสวนโรค',
#  'ระหว่างสอบสวน',
#  'รับจ้างขนของที่ตลาดท่ายาง',
#  'ร้านอาหาร',
#  'ศูนย์กักกัน ผู้ต้องกัก',
#  'สถานที่ทำงาน',
#  'สถานบันเทิง',
#  'สน.วัดพระยาไกร',
#  'สนามมวย',
#  'สัมผัสผู้ติดเชื้อยืนยัน\nอยู่ระหว่างสอบสวน',
#  'สัมผัสผู้ติดเชื้อยืนยัน อยู่ระหว่างสอบสวน',
#  'สัมผัสผู้ป่วยที่ติดโควิด',
#  'สัมผัสผู้ป่วยยืนยัน',
#  'สัมผัสผู้ป่วยยืนยัน \n อยู่ระหว่างสอบสวน',
#  'สัมผัสผู้ป่วยยืนยัน (ยังไม่สามารถระบุได้)',
#  'สัมผัสผู้ป่วยยืนยัน ภายในครอบครัว/ชุมชน/เพื่อน',
#  'สัมผัสผู้ป่วยยืนยัน อยุ๋ระหว่างสอบสวน',
#  'สัมผัสผู้ป่วยยืนยัน อยู่ระหว่างสอบสวน',
#  'สัมผัสผู้ป่วยยืนยันเพื่อนร่วมงาน',
#  'สัมผัสผู้เดินทางจากต่างประเทศ',
#  'สัมผัสสามีสะอาด เขตบ้าน (รพ.มหาชัย 2)',
#  'สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้',
#  'สัมผัสใกล้ชิดผู้ป่วยยันยันก่อนหน้า',
#  'สัมผัสใกล้ชิดผู้ป่วยยืนยันก่อนหน้า',
#  'สัมผัสในสถานพยาบาล',
#  'อยุ่ระหว่างสอบสวน',
#  'อยู่ระหว่างการสอบสวน',
#  'อยู่ระหว่างการสอบสวน\n',
#  'อยู่ระหว่างสอบสวน',
#  'อยู่ระหว่างสอบสวนโรค',
#  'อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงานใกล้ชิดสัมผัสชาวต่างชาติ เป็นต้น',
#  'อาศัย/เดินทางไปในพื้นที่ที่มีการระบาด',
#  'อื่น',
#  'อื่นๆ',
#  'เดินทางมาจากพื้นที่จังหวัดเสี่ยง',
#  'เดินทางมาจากพื้นที่มีการระบาดของโรค',
#  'เดินทางมาจากพื้นที่เสี่ยง จ.กรุงเทพฯ จอมทอง',
#  'เดินทางมาจากพื้นที่เสี่ยงที่มีการระบาดของโรค',
#  'แรงงานต่างด้าวตรวจก่อนขึ้นทะเบียน',
#  'ไปยัง/มาจาก พื้นที่ระบาดกรุงเทพมหานครมหานคร',
#  'ไปยังพื้นที่ที่มีการระบาด',
#  'ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว',
#  'ไปสถานที่เสี่ยง เช่น ตลาด สถานที่ชุมชน',
#  'ไปสถานที่แออัด เช่น งานแฟร์ คอนเสิร์ต',
#  'ไปเที่ยวสถานบันเทิงในอุบลที่พบการระบาดของโรค Ubar',
#  'ไปแหล่งชุมชน/สถานที่คนหนาแน่น',
#  'ไม่มีข้อมูล'}

# %% [markdown]
# ### Handling Missing Value 3 (แทนด้วย class ใหม่ (ค่าที่เหมาะสม))

# %%
set(data_cases['Unit'])
# Out:
# {' วัน', ' เดือน', nan, 'ปี', 'วัน', 'เดือน'}

# %%
data_cases[['Unit']] = data_cases[['Unit']].fillna('ปี?')

# %%
data_cases.isnull().any()
# Out:
# No.                       True
# announce_date             True
# Notified date             True
# sex                       True
# age                       True
# Unit                     False
# nationality               True
# province_of_isolation     True
# risk                     False
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %% [markdown]
# ###Handling Missing Value 4 (แทนด้วย ค่ากลาง)
# ถ้าเป็น numeric ใช้ mean

# %%
data_cases[['age']].mean()
# Out:
# age    35.519252
# dtype: float64

# %%
data_cases[['age']].dropna().mean()
# Out:
# age    35.519252
# dtype: float64

# %%
# หา mean
avg_age = data_cases[['age']].mean()
# เติม mean ลงไปแทนค่า missing
data_cases[['age']] = data_cases[['age']].fillna(avg_age)

# %%
data_cases.isnull().any()
# Out:
# No.                       True
# announce_date             True
# Notified date             True
# sex                       True
# age                      False
# Unit                     False
# nationality               True
# province_of_isolation     True
# risk                     False
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %%
data_cases[['age']].mean()
# Out:
# age    35.519252
# dtype: float64

# %%
data_cases[['nationality']].mode()
# Out:
#   nationality
# 0    Thailand

# %%
data_cases[['nationality']].mode().iloc[0,0]
# Out:
# 'Thailand'

# %%
data_cases['nationality'].mode()
# Out:
# 0    Thailand
# dtype: object

# %%
# หา mode
mode_nation = data_cases[['nationality']].mode().iloc[0,0]
# เติม mean ลงไปแทนค่า missing
data_cases[['nationality']] = data_cases[['nationality']].fillna(mode_nation)

# %%
data_cases.isnull().any()
# Out:
# No.                       True
# announce_date             True
# Notified date             True
# sex                       True
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation     True
# risk                     False
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %% [markdown]
# ถ้าเป็น ordinal ใช้ median
#
# เติมด้วยค่าของ column ใกล้เคียง (เดี๋ยวย้อนกลับมา)

# %%
data_cases.head(20)
# Out:
#      No. announce_date  ... province_of_onset district_of_onset
# 0    1.0     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1    2.0     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2    3.0     22/1/2020  ...            นครปฐม             เมือง
# 3    4.0     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4    5.0     24/1/2020  ...     กรุงเทพมหานคร               NaN
# 5    6.0     25/1/2020  ...     กรุงเทพมหานคร               NaN
# 6    7.0     26/1/2020  ...     กรุงเทพมหานคร               NaN
# 7    8.0     26/1/2020  ...   ประจวบคีรีขันธ์            หัวหิน
# 8    9.0     28/1/2020  ...     กรุงเทพมหานคร               NaN
# 9   10.0     28/1/2020  ...           นนทบุรี               NaN
# 10  11.0     28/1/2020  ...     กรุงเทพมหานคร               NaN
# 11  12.0     28/1/2020  ...     กรุงเทพมหานคร               NaN
# 12  13.0     28/1/2020  ...     กรุงเทพมหานคร               NaN
# 13  14.0     28/1/2020  ...            ภูเก็ต             เมือง
# 14  15.0     31/1/2020  ...     กรุงเทพมหานคร               NaN
# 15  16.0     31/1/2020  ...     กรุงเทพมหานคร               NaN
# 16  17.0     31/1/2020  ...         เชียงใหม่             หางดง
# 17  18.0     31/1/2020  ...     กรุงเทพมหานคร               NaN
# 18  19.0     31/1/2020  ...     กรุงเทพมหานคร               NaN
# 19  20.0      4/2/2020  ...     กรุงเทพมหานคร               NaN
#
# [20 rows x 11 columns]

# %% [markdown]
# ###Handling Missing Value 5 (แทนด้วย ค่ากลางของ samples ใน class เดียวกัน)

# %%
data_cases2 = pd.read_csv(os.path.join(path,'confirmed-cases (5).csv'))
data_cases2
# Out:
#              No. announce_date  ... province_of_onset district_of_onset
# 0            1.0     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1            2.0     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3.0     22/1/2020  ...            นครปฐม             เมือง
# 3            4.0     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5.0     24/1/2020  ...     กรุงเทพมหานคร               NaN
# ...          ...           ...  ...               ...               ...
# 543301  543302.0     28/7/2021  ...        สุพรรณบุรี               NaN
# 543302  543303.0     28/7/2021  ...        สุพรรณบุรี               NaN
# 543303  543304.0     28/7/2021  ...        สุพรรณบุรี               NaN
# 543304  543305.0     28/7/2021  ...           ปัตตานี               NaN
# 543305       NaN           NaN  ...               NaN               NaN
#
# [543306 rows x 11 columns]

# %% [markdown]
# ###Select data by values [PD]

# %% [markdown]
# การเลือก record สามารถเลือกโดยใช้ list ของ boolean(ความยาวของ list เท่ากับ จำนวน record)
#
# ชื่อตาราง[list ของ boolean]
#
# สร้าง list ของ boolean

# %%
data_cases2['risk'] == 'ทัณฑสถาน/เรือนจำ'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 543301     True
# 543302     True
# 543303     True
# 543304     True
# 543305    False
# Name: risk, Length: 543306, dtype: bool

# %% [markdown]
# นำ list ของ boolean มาเลือกค่าในตาราง

# %%
data_cases2[data_cases2['risk'] == 'ทัณฑสถาน/เรือนจำ']
# Out:
#              No. announce_date  ... province_of_onset district_of_onset
# 100018  100019.0     16/5/2021  ...        ฉะเชิงเทรา  เมืองฉะเชิงเทรา‎
# 100019  100020.0     16/5/2021  ...        ฉะเชิงเทรา  เมืองฉะเชิงเทรา‎
# 101468  101469.0     17/5/2021  ...               NaN               NaN
# 101469  101470.0     17/5/2021  ...               NaN               NaN
# 101470  101471.0     17/5/2021  ...               NaN               NaN
# ...          ...           ...  ...               ...               ...
# 543300  543301.0     28/7/2021  ...        สุพรรณบุรี               NaN
# 543301  543302.0     28/7/2021  ...        สุพรรณบุรี               NaN
# 543302  543303.0     28/7/2021  ...        สุพรรณบุรี               NaN
# 543303  543304.0     28/7/2021  ...        สุพรรณบุรี               NaN
# 543304  543305.0     28/7/2021  ...           ปัตตานี               NaN
#
# [41778 rows x 11 columns]

# %% [markdown]
# สร้าง list ของ boolean

# %%
data_cases2['age'] > 70
# Out:
# 0         False
# 1          True
# 2          True
# 3         False
# 4         False
#           ...
# 543301    False
# 543302    False
# 543303    False
# 543304    False
# 543305    False
# Name: age, Length: 543306, dtype: bool

# %% [markdown]
# เลือก

# %%
data_cases2[data_cases2['age'] > 70]
# Out:
#              No. announce_date  ... province_of_onset district_of_onset
# 1            2.0     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3.0     22/1/2020  ...            นครปฐม             เมือง
# 7            8.0     26/1/2020  ...   ประจวบคีรีขันธ์            หัวหิน
# 82          83.0     15/3/2020  ...     กรุงเทพมหานคร               NaN
# 119        120.0     16/3/2020  ...        ฉะเชิงเทรา               NaN
# ...          ...           ...  ...               ...               ...
# 543095  543096.0     28/7/2021  ...     กรุงเทพมหานคร            จอมทอง
# 543101  543102.0     28/7/2021  ...     กรุงเทพมหานคร       ราษฎร์บูรณะ
# 543102  543103.0     28/7/2021  ...     กรุงเทพมหานคร            ประเวศ
# 543270  543271.0     28/7/2021  ...        สุพรรณบุรี               NaN
# 543272  543273.0     28/7/2021  ...        สุพรรณบุรี               NaN
#
# [12344 rows x 11 columns]

# %%
blist_age70up = data_cases2['age'] > 70

# %%
blist_female = data_cases2['sex'] == 'หญิง'
blist_female
# Out:
# 0          True
# 1          True
# 2          True
# 3         False
# 4          True
#           ...
# 543301    False
# 543302    False
# 543303    False
# 543304    False
# 543305    False
# Name: sex, Length: 543306, dtype: bool

# %% [markdown]
# เราใช้ & (and) และ | (or) ในการรวม list ของ boolean

# %%
blist_age70up & blist_female
# Out:
# 0         False
# 1          True
# 2          True
# 3         False
# 4         False
#           ...
# 543301    False
# 543302    False
# 543303    False
# 543304    False
# 543305    False
# Length: 543306, dtype: bool

# %%
data_cases2[blist_age70up & blist_female]
# Out:
#              No. announce_date  ... province_of_onset district_of_onset
# 1            2.0     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3.0     22/1/2020  ...            นครปฐม             เมือง
# 7            8.0     26/1/2020  ...   ประจวบคีรีขันธ์            หัวหิน
# 476        477.0     22/3/2020  ...     กรุงเทพมหานคร         ภาษีเจริญ
# 564        565.0     22/3/2020  ...           นนทบุรี               NaN
# ...          ...           ...  ...               ...               ...
# 543054  543055.0     28/7/2021  ...     กรุงเทพมหานคร            ประเวศ
# 543086  543087.0     28/7/2021  ...     กรุงเทพมหานคร            บางบอน
# 543088  543089.0     28/7/2021  ...     กรุงเทพมหานคร          ลาดพร้าว
# 543095  543096.0     28/7/2021  ...     กรุงเทพมหานคร            จอมทอง
# 543102  543103.0     28/7/2021  ...     กรุงเทพมหานคร            ประเวศ
#
# [6739 rows x 11 columns]

# %% [markdown]
# Quiz 4 + HW
# หา records ต่อไปนี้
#
#  1.  records ที่ กักตัวที่ขอนแก่น
#  2.  records ที่ กักตัวที่ ขอนแก่น+โคราช+อุดร
#  3.  records ที่ เป็นผู้หญิงที่พบเชื้อที่ กทม
#  4.  records ที่ เป็นผู้ชาย อายุ 18-22 ปี ที่กักตัวที่เชียงใหม่
#  5.  หาอายุเฉลี่ยของคนที่พบเชื้อที่ ขอนแก่น

# %% [markdown]
# 1

# %%
data_cases2[data_cases2['province_of_isolation']=='ขอนแก่น']
# Out:
#              No. announce_date  ... province_of_onset district_of_onset
# 181        182.0     18/3/2020  ...           ขอนแก่น             เมือง
# 463        464.0     22/3/2020  ...           ขอนแก่น             เมือง
# 1467      1468.0     30/3/2020  ...           ขอนแก่น             เมือง
# 1971      1972.0      3/4/2020  ...           ขอนแก่น             เมือง
# 2638      2639.0     15/4/2020  ...           ขอนแก่น            น้ำพอง
# ...          ...           ...  ...               ...               ...
# 535470  535471.0     28/7/2021  ...           ขอนแก่น            น้ำพอง
# 535471  535472.0     28/7/2021  ...           ขอนแก่น           บ้านฝาง
# 535472  535473.0     28/7/2021  ...           ขอนแก่น              ศิลา
# 535473  535474.0     28/7/2021  ...           ขอนแก่น             เมือง
# 535474  535475.0     28/7/2021  ...           ขอนแก่น         อุบลรัตน์
#
# [3923 rows x 11 columns]

# %% [markdown]
# 2

# %%
data_cases2[(data_cases2['province_of_isolation'] == 'ขอนแก่น') | (data_cases2['province_of_isolation'] == 'นครราชสีมา') | (data_cases2['province_of_isolation'] == 'อุดรธานี')]
# Out:
#              No. announce_date  ... province_of_onset district_of_onset
# 181        182.0     18/3/2020  ...           ขอนแก่น             เมือง
# 189        190.0     18/3/2020  ...        นครราชสีมา             พิมาย
# 207        208.0     18/3/2020  ...     กรุงเทพมหานคร               NaN
# 212        213.0     18/3/2020  ...        นครราชสีมา       วังน้ำเขียว
# 284        285.0     20/3/2020  ...        นครราชสีมา   เมืองนครราชสีมา
# ...          ...           ...  ...               ...               ...
# 536858  536859.0     28/7/2021  ...               NaN               NaN
# 536859  536860.0     28/7/2021  ...               NaN               NaN
# 536860  536861.0     28/7/2021  ...               NaN               NaN
# 536861  536862.0     28/7/2021  ...               NaN               NaN
# 536862  536863.0     28/7/2021  ...               NaN               NaN
#
# [11498 rows x 11 columns]

# %% [markdown]
# 3

# %%
data_cases2[(data_cases2['sex'] == 'หญิง') & (data_cases2['province_of_isolation'] == 'กรุงเทพมหานคร')]
# Out:
#              No. announce_date  ... province_of_onset district_of_onset
# 0            1.0     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1            2.0     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 5            6.0     25/1/2020  ...     กรุงเทพมหานคร               NaN
# 6            7.0     26/1/2020  ...     กรุงเทพมหานคร               NaN
# 19          20.0      4/2/2020  ...     กรุงเทพมหานคร               NaN
# ...          ...           ...  ...               ...               ...
# 543100  543101.0     28/7/2021  ...     กรุงเทพมหานคร             ดุสิต
# 543102  543103.0     28/7/2021  ...     กรุงเทพมหานคร            ประเวศ
# 543148  543149.0     28/7/2021  ...     กรุงเทพมหานคร               NaN
# 543149  543150.0     28/7/2021  ...     กรุงเทพมหานคร               NaN
# 543150  543151.0     28/7/2021  ...     กรุงเทพมหานคร               NaN
#
# [70793 rows x 11 columns]

# %% [markdown]
# 4

# %%
data_cases2[(data_cases2['sex'] == 'ชาย') & (data_cases2['age'] >= 18 )& (data_cases2['age'] <= 22 )& (data_cases2['province_of_isolation'] == 'เชียงใหม่')]
# Out:
#              No. announce_date  ... province_of_onset district_of_onset
# 1407      1408.0     30/3/2020  ...         เชียงใหม่             เมือง
# 30340    30341.0      9/4/2021  ...         เชียงใหม่    เมืองเชียงใหม่
# 31499    31500.0     10/4/2021  ...         เชียงใหม่               NaN
# 31500    31501.0     10/4/2021  ...         เชียงใหม่               NaN
# 31501    31502.0     10/4/2021  ...         เชียงใหม่               NaN
# ...          ...           ...  ...               ...               ...
# 512632  512633.0     27/7/2021  ...         เชียงใหม่               NaN
# 512648  512649.0     27/7/2021  ...         เชียงใหม่             หางดง
# 526967  526968.0     28/7/2021  ...         เชียงใหม่          เชียงดาว
# 526977  526978.0     28/7/2021  ...               NaN               NaN
# 526991  526992.0     28/7/2021  ...         เชียงใหม่         ไชยปราการ
#
# [416 rows x 11 columns]

# %% [markdown]
# 5

# %%
data_cases2[(data_cases2['province_of_isolation'] == 'ขอนแก่น')]
# Out:
#              No. announce_date  ... province_of_onset district_of_onset
# 181        182.0     18/3/2020  ...           ขอนแก่น             เมือง
# 463        464.0     22/3/2020  ...           ขอนแก่น             เมือง
# 1467      1468.0     30/3/2020  ...           ขอนแก่น             เมือง
# 1971      1972.0      3/4/2020  ...           ขอนแก่น             เมือง
# 2638      2639.0     15/4/2020  ...           ขอนแก่น            น้ำพอง
# ...          ...           ...  ...               ...               ...
# 535470  535471.0     28/7/2021  ...           ขอนแก่น            น้ำพอง
# 535471  535472.0     28/7/2021  ...           ขอนแก่น           บ้านฝาง
# 535472  535473.0     28/7/2021  ...           ขอนแก่น              ศิลา
# 535473  535474.0     28/7/2021  ...           ขอนแก่น             เมือง
# 535474  535475.0     28/7/2021  ...           ขอนแก่น         อุบลรัตน์
#
# [3923 rows x 11 columns]

# %%
Avg_KK = data_cases2[(data_cases2['province_of_isolation'] == 'ขอนแก่น')].mean()
Avg_KK
# Out:
# No.    374497.513128
# age        34.822239
# dtype: float64

# %% [markdown]
# 5หาอายุเฉลี่ยของคนที่พบเชื้อที่ ขอนแก่น

# %%
KK_cases = data_cases2['province_of_onset']=='ขอนแก่น'
data_cases2[KK_cases]['age'].mean()
# Out:
# 34.17120146744115

# %% [markdown]
# ### พบที่ขอนแก่น

# %%
data_cases2[KK_cases]
# Out:
#              No. announce_date  ... province_of_onset district_of_onset
# 181        182.0     18/3/2020  ...           ขอนแก่น             เมือง
# 463        464.0     22/3/2020  ...           ขอนแก่น             เมือง
# 1467      1468.0     30/3/2020  ...           ขอนแก่น             เมือง
# 1971      1972.0      3/4/2020  ...           ขอนแก่น             เมือง
# 2638      2639.0     15/4/2020  ...           ขอนแก่น            น้ำพอง
# ...          ...           ...  ...               ...               ...
# 536032  536033.0     28/7/2021  ...           ขอนแก่น       หนองสองห้อง
# 541982  541983.0     28/7/2021  ...           ขอนแก่น      เมืองขอนแก่น
# 542005  542006.0     28/7/2021  ...           ขอนแก่น           ภูเวียง
# 542013  542014.0     28/7/2021  ...           ขอนแก่น      เมืองขอนแก่น
# 542221  542222.0     28/7/2021  ...           ขอนแก่น           บ้านไผ่
#
# [3307 rows x 11 columns]

# %% [markdown]
# ##เอาค่า mean ไปติมตรง missing column 'age'

# %%
data_KK = data_cases2[KK_cases]
data_KK.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation    False
# risk                      True
# province_of_onset        False
# district_of_onset         True
# dtype: bool

# %%
 data_KK[['age']] = data_KK[['age']].fillna(KK_mean)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-82-0a0bfcb631b0> in <module>()
# ----> 1 data_KK[['age']] = data_KK[['age']].fillna(KK_mean)
#
# NameError: name 'KK_mean' is not defined

# %%
data_KK.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation    False
# risk                      True
# province_of_onset        False
# district_of_onset         True
# dtype: bool

# %%
data_KK
# Out:
#              No. announce_date  ... province_of_onset district_of_onset
# 181        182.0     18/3/2020  ...           ขอนแก่น             เมือง
# 463        464.0     22/3/2020  ...           ขอนแก่น             เมือง
# 1467      1468.0     30/3/2020  ...           ขอนแก่น             เมือง
# 1971      1972.0      3/4/2020  ...           ขอนแก่น             เมือง
# 2638      2639.0     15/4/2020  ...           ขอนแก่น            น้ำพอง
# ...          ...           ...  ...               ...               ...
# 536032  536033.0     28/7/2021  ...           ขอนแก่น       หนองสองห้อง
# 541982  541983.0     28/7/2021  ...           ขอนแก่น      เมืองขอนแก่น
# 542005  542006.0     28/7/2021  ...           ขอนแก่น           ภูเวียง
# 542013  542014.0     28/7/2021  ...           ขอนแก่น      เมืองขอนแก่น
# 542221  542222.0     28/7/2021  ...           ขอนแก่น           บ้านไผ่
#
# [3307 rows x 11 columns]

# %% [markdown]
# เติมค่า mean แทน missimg ของเชียงใหม่

# %%
# หาค่า mean ของเชียงใหม่
CM_cases = data_cases2['province_of_onset'] == 'เชียงใหม่'
CM_mean = data_cases2[CM_cases]['age'].mean()

# เลือกมาเฉพาะ data เชียงใหม่
data_CM = data_cases2[CM_cases]

# เติมค่า mean แทน missing
data_CM[['age']] = data_CM[['age']].fillna(CM_mean)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
data_CM
# Out:
#              No. announce_date  ... province_of_onset district_of_onset
# 16          17.0     31/1/2020  ...         เชียงใหม่             หางดง
# 91          92.0     15/3/2020  ...         เชียงใหม่            แม่ริม
# 185        186.0     18/3/2020  ...         เชียงใหม่          นครพิงค์
# 192        193.0     18/3/2020  ...         เชียงใหม่               NaN
# 252        253.0     19/3/2020  ...         เชียงใหม่               NaN
# ...          ...           ...  ...               ...               ...
# 526996  526997.0     28/7/2021  ...         เชียงใหม่            แม่วาง
# 526998  526999.0     28/7/2021  ...         เชียงใหม่    เมืองเชียงใหม่
# 535869  535870.0     28/7/2021  ...         เชียงใหม่          เชียงดาว
# 541968  541969.0     28/7/2021  ...         เชียงใหม่         สันป่าตอง
# 542506  542507.0     28/7/2021  ...         เชียงใหม่    เมืองเชียงใหม่
#
# [4170 rows x 11 columns]

# %% [markdown]
# ###ต่อตารางแนวแกน Y [PD]

# %%
data_CMKK = pd.concat([data_CM,data_KK])
data_CMKK
# Out:
#              No. announce_date  ... province_of_onset district_of_onset
# 16          17.0     31/1/2020  ...         เชียงใหม่             หางดง
# 91          92.0     15/3/2020  ...         เชียงใหม่            แม่ริม
# 185        186.0     18/3/2020  ...         เชียงใหม่          นครพิงค์
# 192        193.0     18/3/2020  ...         เชียงใหม่               NaN
# 252        253.0     19/3/2020  ...         เชียงใหม่               NaN
# ...          ...           ...  ...               ...               ...
# 536032  536033.0     28/7/2021  ...           ขอนแก่น       หนองสองห้อง
# 541982  541983.0     28/7/2021  ...           ขอนแก่น      เมืองขอนแก่น
# 542005  542006.0     28/7/2021  ...           ขอนแก่น           ภูเวียง
# 542013  542014.0     28/7/2021  ...           ขอนแก่น      เมืองขอนแก่น
# 542221  542222.0     28/7/2021  ...           ขอนแก่น           บ้านไผ่
#
# [7477 rows x 11 columns]

# %% [markdown]
# ##Handling Missing Value 5 (แทนด้วย ค่ากลางของ samples ใน class เดียวกัน) ต่อ

# %%
data_cases2
# Out:
#              No. announce_date  ... province_of_onset district_of_onset
# 0            1.0     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1            2.0     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3.0     22/1/2020  ...            นครปฐม             เมือง
# 3            4.0     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5.0     24/1/2020  ...     กรุงเทพมหานคร               NaN
# ...          ...           ...  ...               ...               ...
# 543301  543302.0     28/7/2021  ...        สุพรรณบุรี               NaN
# 543302  543303.0     28/7/2021  ...        สุพรรณบุรี               NaN
# 543303  543304.0     28/7/2021  ...        สุพรรณบุรี               NaN
# 543304  543305.0     28/7/2021  ...           ปัตตานี               NaN
# 543305       NaN           NaN  ...       ไม่มีข้อมูล               NaN
#
# [543306 rows x 11 columns]

# %%
data_cases2[['province_of_onset']] = data_cases2[['province_of_onset']].fillna('ไม่มีข้อมูล')

# %% [markdown]
# หาจังหวัดทั้งหทด

# %%
all_cities = set(data_cases2['province_of_onset'])
all_cities
# Out:
# {'กระบี่',
#  'กรุงเทพมหานคร',
#  'กัมพูชา',
#  'กาญจนบุรี',
#  'กาฬสินธิ์',
#  'กาฬสินธุ์',
#  'กาฬสินธ์ุ',
#  'กาฬสิินธุ์',
#  'กำแพงเพชร',
#  'ขอนแก่น',
#  'ขอนแก่่น',
#  'จ.ปัตตานี',
#  'จังหวัดร้อยเอ็ด',
#  'จันทบุรี',
#  'ฉะเชิงเทรา',
#  'ชลบุรี',
#  'ชลบุุรี',
#  'ชัยนาท',
#  'ชัยภูมิ',
#  'ชััยภูมิ',
#  'ชุมพร',
#  'ชุุมพร',
#  'ตรัง',
#  'ตราด',
#  'ตาก',
#  'ธารโต',
#  'นคนปฐม',
#  'นคปฐม',
#  'นครนาชสีมา',
#  'นครนายก',
#  'นครปฐม',
#  'นครประฐม',
#  'นครพนม',
#  'นครราชธสีมา',
#  'นครราชสีมา',
#  'นครศรธรรมาช',
#  'นครศรี',
#  'นครศรีธรรมราช',
#  'นครศรีธรรรมราช',
#  'นครศรีราชสีมา',
#  'นครศรีีธรรมราช',
#  'นครสวรรค์',
#  'นครสววรค์',
#  'นตรปฐม',
#  'นนทบุรี',
#  'นนทุบรี',
#  'นราธิวาส',
#  'นาราธิวาส',
#  'นาวัง',
#  'น่าน',
#  'บางกะปิ',
#  'บึงกาฬ',
#  'บึงโขงหลง',
#  'บึึงกาฬ',
#  'บุรีรัมย์',
#  'บุรีรัยม์',
#  'บ้านหลวง',
#  'ปทุมทานี',
#  'ปทุมธานี',
#  'ปทุมธานีี',
#  'ปทุุมธานี',
#  'ประจวบครีขันธ์',
#  'ประจวบคีรีขันธื',
#  'ประจวบคีรีขันธ์',
#  'ปราจีนบุรี',
#  'ปลายพระยา',
#  'ปัตตานี',
#  'ปัตตานี\u200b',
#  'ปัว',
#  'พม่า',
#  'พระนครศรียุธยา',
#  'พระนครศรีอยุทธยา',
#  'พระนครศรีอยุธนา',
#  'พระนครศรีอยุธยา',
#  'พระนครศีรอยุธยา',
#  'พระนครศีอยุธยา',
#  'พระนตรศรีอยุธยา',
#  'พะยา',
#  'พะเยา',
#  'พังงา',
#  'พัทลุง',
#  'พิจิตร',
#  'พิษณุโลก',
#  'ภูเก็ต',
#  'ภูเพียง',
#  'มหาสารคราม',
#  'มหาสารคาม',
#  'มาเลเซีย',
#  'มุกดาหาร',
#  'ยะลา',
#  'ยานนาวา',
#  'ยโสธร',
#  'ระนอง',
#  'ระยอง',
#  'ราชบุรี',
#  'ร้องกวาง',
#  'ร้อยเอ็ด',
#  'ร้อยเอ็็ด',
#  'ร้อยเอ้ด',
#  'ร้้อยเอ็ด',
#  'ลพบรี',
#  'ลพบุรี',
#  'ลพบุุรี',
#  'ลอง',
#  'ลำปาง',
#  'ลำพูน',
#  'วังชิ้น',
#  'ศรีษะเกษ',
#  'ศรีสะเกษ',
#  'ศรีีสะเกษ',
#  'ศีรษะเกษ',
#  'ศีรสะเกษ',
#  'สกลนคร',
#  'สงขขลา',
#  'สงขลา',
#  'สงขลา\u200b',
#  'สตูล',
#  'สถานที่ทำงาน',
#  'สมทรสาคร',
#  'สมุทปราการ',
#  'สมุทรปราการ',
#  'สมุทรปาการ',
#  'สมุทรสงคราม',
#  'สมุทรสงคราม.',
#  'สมุทรสาคร',
#  'สมุทราปราการ',
#  'สมุทราสาคร',
#  'สมุทสงคราม',
#  'สมุทสาคร',
#  'สมุุทรปราการ',
#  'สมุุทรสงคราม',
#  'สมุุทรสาคร',
#  'สมุุทสาคร',
#  'สระบุรี',
#  'สระบุุรี',
#  'สระแก้ว',
#  'สรแก้ว',
#  'สอง',
#  'สองแคว',
#  'สิงห์บุรี',
#  'สุทรปราการ',
#  'สุพรรณบุรี',
#  'สุมทรสาคร',
#  'สุมุทรปราการ',
#  'สุมุทรสาคร',
#  'สุราษฎร์ธานี',
#  'สุรินทร์',
#  'สุุราษฎร์ธานี',
#  'สุโขทัย',
#  'สูงเม่น',
#  'หนองคาย',
#  'หนองบัวลำภู',
#  'หนองบัวลำภูู',
#  'หนองบัวลำำภู',
#  'หนองบััวลำภู',
#  'หนองม่วงไข่',
#  'อยุธยา',
#  'อำนาจเจริญ',
#  'อุดรถานี',
#  'อุดรธานี',
#  'อุดรธานีี',
#  'อุตรดิตถ์',
#  'อุทัยธานี',
#  'อุบลราขธานี',
#  'อุบลราชธานี',
#  'อุยุธยา',
#  'อุุดรธาน',
#  'อุุดรธานี',
#  'อุุตรดิตถ์',
#  'อุุทัยธานี',
#  'อ่างทอง',
#  'ูภูเก็ต',
#  'เชียงราย',
#  'เชียงใหม่',
#  'เชียงใหม่่',
#  'เด่นชัย',
#  'เพชบุรี',
#  'เพชบูรณ์',
#  'เพชรบุรี',
#  'เพชรบูรณ์',
#  'เพชรบูลย์',
#  'เพรชบุรี',
#  'เพรบุรี',
#  'เพรบูรณ์',
#  'เมือง',
#  'เมืองน่าน',
#  'เรือ',
#  'เลย',
#  'เวียงจันทร์',
#  'เวียงสา',
#  'แพร่',
#  'แม่ฮ่องสอน',
#  'ไม่มีข้อมูล',
#  'ไม่ระบุ'}

# %%
fixed_cities = []

for city in all_cities:
    # หาค่า mean ของเชียงใหม่
    X_cases = data_cases2['province_of_onset'] == city
    X_mean = data_cases2[X_cases]['age'].mean()

    # เลือกมาเฉพาะ data เชียงใหม่
    data_X = data_cases2[X_cases]

    # เติมค่า mean แทน missing
    data_X[['age']] = data_X[['age']].fillna(X_mean)

    fixed_cities.append(data_X)


data_cases2_nomissingage = pd.concat(fixed_cities)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
data_cases2_nomissingage
# Out:
#              No. announce_date  ... province_of_onset district_of_onset
# 1089      1090.0     27/3/2020  ...        แม่ฮ่องสอน               NaN
# 1155      1156.0     28/3/2020  ...        แม่ฮ่องสอน               NaN
# 1156      1157.0     28/3/2020  ...        แม่ฮ่องสอน               NaN
# 1157      1158.0     28/3/2020  ...        แม่ฮ่องสอน               NaN
# 1461      1462.0     30/3/2020  ...        แม่ฮ่องสอน               ปาย
# ...          ...           ...  ...               ...               ...
# 541751  541752.0     28/7/2021  ...         เพชรบูรณ์           วังโป่ง
# 541797  541798.0     28/7/2021  ...         เพชรบูรณ์         บึงสามพัน
# 541879  541880.0     28/7/2021  ...         เพชรบูรณ์       วิเชียรบุรี
# 542146  542147.0     28/7/2021  ...         เพชรบูรณ์         บึงสามพัน
# 542382  542383.0     28/7/2021  ...         เพชรบูรณ์       วิเชียรบุรี
#
# [543306 rows x 11 columns]

# %%
data_cases2_nomissingage.isnull().any()
# Out:
# No.                       True
# announce_date             True
# Notified date             True
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation     True
# risk                      True
# province_of_onset        False
# district_of_onset         True
# dtype: bool

# %% [markdown]
# เติม mean ของทั้งตาราง ให้กับ missing ที่ยังเหลืออยู่

# %%
data_cases2_nomissingage[['age']] = data_cases2_nomissingage[['age']].fillna(data_cases2_nomissingage['age'].mean())

# %%
data_cases2_nomissingage.isnull().any()
# Out:
# No.                       True
# announce_date             True
# Notified date             True
# sex                       True
# age                      False
# Unit                      True
# nationality               True
# province_of_isolation     True
# risk                      True
# province_of_onset        False
# district_of_onset         True
# dtype: bool

# %%
data_cases2_nomissingage
# Out:
#              No. announce_date  ... province_of_onset district_of_onset
# 1089      1090.0     27/3/2020  ...        แม่ฮ่องสอน               NaN
# 1155      1156.0     28/3/2020  ...        แม่ฮ่องสอน               NaN
# 1156      1157.0     28/3/2020  ...        แม่ฮ่องสอน               NaN
# 1157      1158.0     28/3/2020  ...        แม่ฮ่องสอน               NaN
# 1461      1462.0     30/3/2020  ...        แม่ฮ่องสอน               ปาย
# ...          ...           ...  ...               ...               ...
# 541751  541752.0     28/7/2021  ...         เพชรบูรณ์           วังโป่ง
# 541797  541798.0     28/7/2021  ...         เพชรบูรณ์         บึงสามพัน
# 541879  541880.0     28/7/2021  ...         เพชรบูรณ์       วิเชียรบุรี
# 542146  542147.0     28/7/2021  ...         เพชรบูรณ์         บึงสามพัน
# 542382  542383.0     28/7/2021  ...         เพชรบูรณ์       วิเชียรบุรี
#
# [543306 rows x 11 columns]

# %% [markdown]
# ### การเรียงข้อมูล [PD]

# %%
data_cases2_nomissingage = data_cases2_nomissingage.sort_values(by=['No.'])

# %%
data_cases2_nomissingage
# Out:
#              No. announce_date  ... province_of_onset district_of_onset
# 0            1.0     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1            2.0     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3.0     22/1/2020  ...            นครปฐม             เมือง
# 3            4.0     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5.0     24/1/2020  ...     กรุงเทพมหานคร               NaN
# ...          ...           ...  ...               ...               ...
# 543301  543302.0     28/7/2021  ...        สุพรรณบุรี               NaN
# 543302  543303.0     28/7/2021  ...        สุพรรณบุรี               NaN
# 543303  543304.0     28/7/2021  ...        สุพรรณบุรี               NaN
# 543304  543305.0     28/7/2021  ...           ปัตตานี               NaN
# 543305       NaN           NaN  ...       ไม่มีข้อมูล               NaN
#
# [543306 rows x 11 columns]

# %% [markdown]
# # outlier

# %% [markdown]
# ข้อมูลที่ออกไปจากกลุ่ม

# %%
from matplotlib import pyplot as plt

# %%
data_dict = plt.boxplot(data_cases2_nomissingage['age'])

# %%
data_dict # curly brackets
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7fd1e708f2d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fd1e7099cd0>,
#   <matplotlib.lines.Line2D at 0x7fd1e7099610>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fd1e706b390>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7fd1e7099d50>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fd1e708f890>,
#   <matplotlib.lines.Line2D at 0x7fd1e708fdd0>]}

# %%
data_dict['boxes']

# %%
data_dict['boxes'][0]

# %%
data_dict['boxes'][0].get_ydata()
# Out:
# array([26., 26., 44., 44., 26.])

# %%
Q1 = data_dict['boxes'][0].get_ydata()[0]

# %%
Q1
# Out:
# 26.0

# %%
data_dict['fliers'][0].get_ydata()
# Out:
# array([ 74.,  73.,  73., ..., 106.,  78.,  72.])

# %%
data_dict['caps'][0].get_ydata()
# Out:
# array([1., 1.])

# %%
data_dict['caps'][0].get_ydata()[0]
# Out:
# 1.0

# %%
data_dict['caps'][1].get_ydata()
# Out:
# array([71., 71.])

# %%
cap1 = data_cases2_nomissingage['age'] >= data_dict['caps'][0].get_ydata()[0]
cap2 = data_cases2_nomissingage['age'] <= data_dict['caps'][1].get_ydata()[0]

data_cases2_nomissingage_nooutlier = data_cases2_nomissingage[cap1 & cap2]
data_cases2_nomissingage_nooutlier
# Out:
#              No. announce_date  ... province_of_onset district_of_onset
# 0            1.0     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 3            4.0     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5.0     24/1/2020  ...     กรุงเทพมหานคร               NaN
# 5            6.0     25/1/2020  ...     กรุงเทพมหานคร               NaN
# 6            7.0     26/1/2020  ...     กรุงเทพมหานคร               NaN
# ...          ...           ...  ...               ...               ...
# 543301  543302.0     28/7/2021  ...        สุพรรณบุรี               NaN
# 543302  543303.0     28/7/2021  ...        สุพรรณบุรี               NaN
# 543303  543304.0     28/7/2021  ...        สุพรรณบุรี               NaN
# 543304  543305.0     28/7/2021  ...           ปัตตานี               NaN
# 543305       NaN           NaN  ...       ไม่มีข้อมูล               NaN
#
# [532385 rows x 11 columns]

# %%
data_dict = plt.boxplot(data_cases2_nomissingage_nooutlier['age'])

# %% [markdown]
# ตัด outlier แบบ manual

# %%
data_cases2_nomissingage[data_cases2_nomissingage['province_of_onset'] != 'ลอง']
# Out:
#              No. announce_date  ... province_of_onset district_of_onset
# 0            1.0     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1            2.0     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3.0     22/1/2020  ...            นครปฐม             เมือง
# 3            4.0     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5.0     24/1/2020  ...     กรุงเทพมหานคร               NaN
# ...          ...           ...  ...               ...               ...
# 543301  543302.0     28/7/2021  ...        สุพรรณบุรี               NaN
# 543302  543303.0     28/7/2021  ...        สุพรรณบุรี               NaN
# 543303  543304.0     28/7/2021  ...        สุพรรณบุรี               NaN
# 543304  543305.0     28/7/2021  ...           ปัตตานี               NaN
# 543305       NaN           NaN  ...       ไม่มีข้อมูล               NaN
#
# [543300 rows x 11 columns]

# %% [markdown]
# ###HW8 + Quiz 5

# %% [markdown]
# เขียนฟังก์ชั่น คำนวณ หา Q1,Q2,Q3,IQR,min,max โดยรับ input เป็น output ของ boxplot

# %% [markdown]
# >
#
#     def box_vals(box_out_dict):
#     #your code1
#     .
#     .
#     .
#     #your codex
#     return q1,q2,q3,iqr,vmin,vmix

# %%
def box_vals(box_out_dict):
    Q1 = box_out_dict['boxes'][0].get_ydata()[0] 
    Q2 = box_out_dict['medians'][0].get_ydata()[0]
    Q3 = box_out_dict['boxes'][0].get_ydata()[2]
    IQR =  Q3 - Q1
    vmin =  box_out_dict['caps'][0].get_ydata()[0]
    vmax =  box_out_dict['caps'][1].get_ydata()[0] 
    return Q1,Q2,Q3,IQR,vmin,vmax

# %%
box_vals(data_dict) ### เรียกใช้ฟังก์ชั่น
# Out:
# (25.0, 35.0, 43.0, 18.0, 1.0, 70.0)

# %%
data_dict = plt.boxplot(data_cases2_nomissingage_nooutlier['age'],vert=False)

# %%
data_dict['boxes'][0].get_xdata()
# Out:
# array([25., 25., 43., 43., 25.])

# %% [markdown]
# Quiz กลุ่ม III แก้ให้ function box_vals สามารถรับ input ที่ box plot วาดแบบแนวนอนได้ (vert = False)

# %%
def box_vals(box_out_dict, vert = True):
  
        q1 = box_out_dict['boxes'][0].get_ydata()[0] 
        q2 = box_out_dict['medians'][0].get_ydata()[0]
        q3 = box_out_dict['boxes'][0].get_ydata()[2]
        iqr =  q3 - q1
        vmin =  box_out_dict['caps'][0].get_ydata()[0]
        vmax =  box_out_dict['caps'][1].get_ydata()[0] 
        if vert == False:
            q1 = box_out_dict['boxes'][0].get_xdata()[0]
            q2 = box_out_dict['medians'][0].get_xdata()[0]
            q3 = box_out_dict['boxes'][0].get_xdata()[2]
            iqr = q3 - q1
            vmin = box_out_dict['caps'][0].get_xdata()[0]
            vmax = box_out_dict['caps'][1].get_xdata()[0]
   
        return q1,q2,q3,iqr,vmin,vmax

# %%
box_vals(data_dict, vert=True)
# Out:
# (0.925, 0.925, 1.075, 0.1499999999999999, 0.9625, 0.9625)

# %%
box_vals(data_dict, vert=False)
# Out:
# (25.0, 35.0, 43.0, 18.0, 1.0, 70.0)

# %% [markdown]
# ### Pandas' looping(.iterrows)

# %%
data_cut = data_cases2_nomissingage.iloc[:10]
data_cut
 #ใช้loc ควบคุม
# Out:
#     No. announce_date  ... province_of_onset district_of_onset
# 0   1.0     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1   2.0     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2   3.0     22/1/2020  ...            นครปฐม             เมือง
# 3   4.0     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4   5.0     24/1/2020  ...     กรุงเทพมหานคร               NaN
# 5   6.0     25/1/2020  ...     กรุงเทพมหานคร               NaN
# 6   7.0     26/1/2020  ...     กรุงเทพมหานคร               NaN
# 7   8.0     26/1/2020  ...   ประจวบคีรีขันธ์            หัวหิน
# 8   9.0     28/1/2020  ...     กรุงเทพมหานคร               NaN
# 9  10.0     28/1/2020  ...           นนทบุรี               NaN
#
# [10 rows x 11 columns]

# %%
for record in data_cut.iterrows():
  print(record)
  print('new row')
# Out:
# (0, No.                                                     1
# announce_date                                   12/1/2020
# Notified date                                         NaN
# sex                                                  หญิง
# age                                                    61
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                       กรุงเทพมหานคร
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# Name: 0, dtype: object)
# new row
# (1, No.                                                     2
# announce_date                                   17/1/2020
# Notified date                                         NaN
# sex                                                  หญิง
# age                                                    74
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                       กรุงเทพมหานคร
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# Name: 1, dtype: object)
# new row
# (2, No.                                                     3
# announce_date                                   22/1/2020
# Notified date                                         NaN
# sex                                                  หญิง
# age                                                    73
# Unit                                                   ปี
# nationality                                      Thailand
# province_of_isolation                              นครปฐม
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                                  นครปฐม
# district_of_onset                                   เมือง
# Name: 2, dtype: object)
# new row
# (3, No.                                                     4
# announce_date                                   22/1/2020
# Notified date                                         NaN
# sex                                                   ชาย
# age                                                    68
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                       กรุงเทพมหานคร
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# Name: 3, dtype: object)
# new row
# (4, No.                                                     5
# announce_date                                   24/1/2020
# Notified date                                         NaN
# sex                                                  หญิง
# age                                                    66
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                             นนทบุรี
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# Name: 4, dtype: object)
# new row
# (5, No.                                                     6
# announce_date                                   25/1/2020
# Notified date                                         NaN
# sex                                                  หญิง
# age                                                    33
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                       กรุงเทพมหานคร
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# Name: 5, dtype: object)
# new row
# (6, No.                                                     7
# announce_date                                   26/1/2020
# Notified date                                         NaN
# sex                                                  หญิง
# age                                                    57
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                       กรุงเทพมหานคร
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# Name: 6, dtype: object)
# new row
# (7, No.                                                     8
# announce_date                                   26/1/2020
# Notified date                                         NaN
# sex                                                  หญิง
# age                                                    73
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                     ประจวบคีรีขันธ์
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                         ประจวบคีรีขันธ์
# district_of_onset                                  หัวหิน
# Name: 7, dtype: object)
# new row
# (8, No.                                                     9
# announce_date                                   28/1/2020
# Notified date                                         NaN
# sex                                                   ชาย
# age                                                    63
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                       กรุงเทพมหานคร
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# Name: 8, dtype: object)
# new row
# (9, No.                                                    10
# announce_date                                   28/1/2020
# Notified date                                         NaN
# sex                                                  หญิง
# age                                                    28
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                             นนทบุรี
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                                 นนทบุรี
# district_of_onset                                     NaN
# Name: 9, dtype: object)
# new row

# %%
for record in data_cut.iterrows():
  print(record[1]['province_of_isolation'])
  print('new row')
# Out:
# กรุงเทพมหานคร
# new row
# กรุงเทพมหานคร
# new row
# นครปฐม
# new row
# กรุงเทพมหานคร
# new row
# นนทบุรี
# new row
# กรุงเทพมหานคร
# new row
# กรุงเทพมหานคร
# new row
# ประจวบคีรีขันธ์
# new row
# กรุงเทพมหานคร
# new row
# นนทบุรี
# new row

# %%
for index in range(data_cut.shape[0]): 
  print(data_cut.iloc[index,7])
  print('new row')
# Out:
# กรุงเทพมหานคร
# new row
# กรุงเทพมหานคร
# new row
# นครปฐม
# new row
# กรุงเทพมหานคร
# new row
# นนทบุรี
# new row
# กรุงเทพมหานคร
# new row
# กรุงเทพมหานคร
# new row
# ประจวบคีรีขันธ์
# new row
# กรุงเทพมหานคร
# new row
# นนทบุรี
# new row

# %% [markdown]
# การรวมตาราง (ต่อตารางในแนวแกน X)

# %%
os.path.join(path,'search_click.csv')
# Out:
# '/content/drive/My Drive/DWDM2021_DATA/search_click.csv'

# %%
search_click = pd.read_csv(os.path.join(path,'search_click (1).csv'))
w_restaurant = pd.read_csv(os.path.join(path,'w_restaurant (2).csv'))

# %%
search_click.head()
# Out:
#   click_timestamp                             search_id  ...  time_diff_nanos   ads
# 0         11:38.9  5c004472-5ecc-4159-9698-9f329b8e26e1  ...     2.222400e+15  True
# 1         30:51.3  5f34eca0-c04e-4c10-b600-54aa447dbd8e  ...     4.608380e+14  True
# 2         32:09.6  8dc6d1f0-11f1-4239-9dd2-5c1674c81224  ...     2.581490e+15  True
# 3         00:59.8  1a5810e9-3d1f-44b9-9a2e-26ede21c524b  ...     1.404580e+15  True
# 4         23:36.8  6bc75e0d-fc65-471e-9926-ff6be6708639  ...     9.333590e+14  True
#
# [5 rows x 6 columns]

# %%
search_click.shape
# Out:
# (1048575, 6)

# %%
print(w_restaurant.shape)
w_restaurant.head()
# Out:
# (246847, 32)
#    id              name  domain_id  ...  hotel_restaurant pet_friendly delivery
# 0   2  นครินทร์ทันตกรรม          2  ...               NaN          NaN      NaN
# 1   4      Corner House          1  ...               NaN          NaN      NaN
# 2   5    วัดโลกยสุธาราม          4  ...               NaN          NaN      NaN
# 3   6    นันท์คาราโอเกะ          1  ...               NaN          NaN      NaN
# 4   7       Buono Caffe          1  ...               NaN          NaN      NaN
#
# [5 rows x 32 columns]

# %%
search100 = search_click.iloc[-100:,:]
search100
# Out:
#         click_timestamp  ...    ads
# 1048475         19:00.5  ...  False
# 1048476         18:50.9  ...  False
# 1048477         45:58.0  ...  False
# 1048478         49:08.8  ...  False
# 1048479         19:25.9  ...  False
# ...                 ...  ...    ...
# 1048570         05:28.8  ...  False
# 1048571         15:28.8  ...  False
# 1048572         11:49.4  ...  False
# 1048573         10:33.7  ...  False
# 1048574         13:51.4  ...  False
#
# [100 rows x 6 columns]

# %% [markdown]
# 1.  รวม 2 ตารางเข้าด้วยกัน
# 2.  เลือกมาเฉพาะบาง column จากอีกตารางหนึ่งมาแปะไว้

# %% [markdown]
# **รวม 2 ตาราง(.merge())**

# %%
merged_table = search100.merge(w_restaurant,how='left',left_on='business_id',right_on='id')

# %%
merged_table
# Out:
#    click_timestamp  ... delivery
# 0          19:00.5  ...      NaN
# 1          18:50.9  ...      NaN
# 2          45:58.0  ...      NaN
# 3          49:08.8  ...      NaN
# 4          19:25.9  ...      NaN
# ..             ...  ...      ...
# 95         05:28.8  ...      NaN
# 96         15:28.8  ...      NaN
# 97         11:49.4  ...      1.0
# 98         10:33.7  ...      1.0
# 99         13:51.4  ...      NaN
#
# [100 rows x 38 columns]

# %% [markdown]
# **เลือกมาเฉพาะบาง column จากอีกตารางหนึ่งมาแปะ (.map())**

# %%
search100['business_name'] = search100['business_id'].map(w_restaurant.set_index('id')['name'])
search100
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#         click_timestamp  ...              business_name
# 1048475         19:00.5  ...  บ้านหญิง อีสาน แอนด์ กริล
# 1048476         18:50.9  ...                   ไก่อากง
# 1048477         45:58.0  ...               อร่อย@หัวหิน
# 1048478         49:08.8  ...               อร่อย@หัวหิน
# 1048479         19:25.9  ...                ชาไทยข่อลดา
# ...                 ...  ...                        ...
# 1048570         05:28.8  ...                เสกแจ่วฮ้อน
# 1048571         15:28.8  ...      ก๋วยเตี๋ยวหมูหน่อกะลา
# 1048572         11:49.4  ...        Laemcharoen Seafood
# 1048573         10:33.7  ...       เอี่ยวไถ่ สุกี้โบราณ
# 1048574         13:51.4  ...                    Icy-me
#
# [100 rows x 7 columns]

# %% [markdown]
# ***ตารางรอง(ตาารางข้างขวา)ต้องไม่มี index ซ้ำ**

# %% [markdown]
# **Group by (pandas)**

# %%
search100.groupby('business_id').count()
# Out:
#              click_timestamp  search_id  ...  ads  business_name
# business_id                              ...
# 9640.0                     1          1  ...    1              1
# 11387.0                    1          1  ...    1              1
# 12133.0                    1          1  ...    1              1
# 44441.0                    3          3  ...    3              3
# 61441.0                    4          4  ...    4              4
# ...                      ...        ...  ...  ...            ...
# 321885.0                   1          1  ...    1              1
# 323374.0                   1          1  ...    1              1
# 331866.0                   1          1  ...    1              1
# 333433.0                   1          1  ...    1              1
# 338544.0                   1          1  ...    1              1
#
# [70 rows x 6 columns]

# %% [markdown]
# ร้านไหนมีคน click เข้าไปดูมากที่สุด โดยพิจารณาจาก การ search 100 ครั้งล่าสุด

# %%
search100.groupby('business_id').count().sort_values(by=['search_id'],ascending=False)
# Out:
#              click_timestamp  search_id  ...  ads  business_name
# business_id                              ...
# 130270.0                   5          5  ...    5              5
# 61441.0                    4          4  ...    4              4
# 98956.0                    4          4  ...    4              4
# 109141.0                   3          3  ...    3              3
# 207208.0                   3          3  ...    3              3
# ...                      ...        ...  ...  ...            ...
# 196321.0                   1          1  ...    1              1
# 11387.0                    1          1  ...    1              1
# 204481.0                   1          1  ...    1              1
# 206253.0                   1          1  ...    1              1
# 338544.0                   1          1  ...    1              1
#
# [70 rows x 6 columns]

# %%
w_restaurant[w_restaurant['id']==130270]
# Out:
#            id         name  domain_id  ...  hotel_restaurant pet_friendly delivery
# 83878  130270  Audrey Café          1  ...               NaN          NaN      NaN
#
# [1 rows x 32 columns]

# %% [markdown]
# แต่ละจังหวัดมีอายุเฉลี่ยนของคนที่ตรวจพบโรคเป็นกี่ปี

# %%
data_cases2
# Out:
#              No. announce_date  ... province_of_onset district_of_onset
# 0            1.0     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1            2.0     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3.0     22/1/2020  ...            นครปฐม             เมือง
# 3            4.0     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5.0     24/1/2020  ...     กรุงเทพมหานคร               NaN
# ...          ...           ...  ...               ...               ...
# 543301  543302.0     28/7/2021  ...        สุพรรณบุรี               NaN
# 543302  543303.0     28/7/2021  ...        สุพรรณบุรี               NaN
# 543303  543304.0     28/7/2021  ...        สุพรรณบุรี               NaN
# 543304  543305.0     28/7/2021  ...           ปัตตานี               NaN
# 543305       NaN           NaN  ...       ไม่มีข้อมูล               NaN
#
# [543306 rows x 11 columns]

# %%
data_cases2.groupby('province_of_onset').mean().sort_values(by=['age'])
# Out:
#                              No.   age
# province_of_onset
# นครศรีีธรรมราช     378103.000000   2.0
# ปลายพระยา          378139.000000  15.0
# จ.ปัตตานี          342312.000000  16.0
# นาวัง              312748.000000  19.0
# สมทรสาคร           507280.000000  19.0
# ...                          ...   ...
# สูงเม่น            403498.333333   NaN
# หนองม่วงไข่        403499.000000   NaN
# เด่นชัย            403504.500000   NaN
# เมืองน่าน          391995.222222   NaN
# เวียงสา            392002.600000   NaN
#
# [194 rows x 2 columns]

# %% [markdown]
#  HW + Quiz
#
# 1.  (จากตาราง w_restaurant กับ search_click) หา จังหวัดที่มีคนเข้าไปดูผลการ search 3 อันดับแรก
# 2.  (จากตาราง w_restaurant กับ search_click) เมืองไหนมีค่าเฉลี่ยของ 'weighted_average_rating' สูงที่สุด
# 3.  (จากตาราง confirmed-cases) เรียงลำดับ risk ที่ทำให้คนติดโรค 5 อันดับแรก
# 4.  (จากตาราง confirmed-cases) หาจังหวัดที่มีคนกักตัวมากที่สุด 10 อันดับ

# %% [markdown]
# ข้อ1

# %%
merged_table.groupby('city_name').count()
# Out:
#                              click_timestamp  search_id  ...  pet_friendly  delivery
# city_name                                                ...
# Bangkok Metropolitan Region               83         83  ...             4        13
# Chaiyaphum                                 1          1  ...             0         0
# Chiang Mai                                 1          1  ...             0         0
# Chon Buri                                  5          5  ...             2         0
# Hua Hin                                    2          2  ...             0         0
# Nakhon Si Thammarat                        1          1  ...             0         0
# Nan                                        1          1  ...             0         0
# Phetchaburi                                1          1  ...             0         0
# Prachin Buri                               1          1  ...             0         0
# Samut Songkhram                            1          1  ...             0         0
# Suphan Buri                                1          1  ...             0         0
# สงขลา                                      1          1  ...             0         0
# เขาใหญ่                                    1          1  ...             0         0
#
# [13 rows x 37 columns]

# %%
search3 = merged_table.groupby('city_name').count().sort_values(by=['search_id'],ascending=False)
search3
# Out:
#                              click_timestamp  search_id  ...  pet_friendly  delivery
# city_name                                                ...
# Bangkok Metropolitan Region               83         83  ...             4        13
# Chon Buri                                  5          5  ...             2         0
# Hua Hin                                    2          2  ...             0         0
# Chaiyaphum                                 1          1  ...             0         0
# Chiang Mai                                 1          1  ...             0         0
# Nakhon Si Thammarat                        1          1  ...             0         0
# Nan                                        1          1  ...             0         0
# Phetchaburi                                1          1  ...             0         0
# Prachin Buri                               1          1  ...             0         0
# Samut Songkhram                            1          1  ...             0         0
# Suphan Buri                                1          1  ...             0         0
# สงขลา                                      1          1  ...             0         0
# เขาใหญ่                                    1          1  ...             0         0
#
# [13 rows x 37 columns]

# %%
search3_cut = search3.iloc[:3,1:2]
search3_cut
# Out:
#                              search_id
# city_name
# Bangkok Metropolitan Region         83
# Chon Buri                            5
# Hua Hin                              2

# %% [markdown]
# ข้อ2

# %%
merged_table.groupby('city_name').count()
# Out:
#                              click_timestamp  search_id  ...  pet_friendly  delivery
# city_name                                                ...
# Bangkok Metropolitan Region               83         83  ...             4        13
# Chaiyaphum                                 1          1  ...             0         0
# Chiang Mai                                 1          1  ...             0         0
# Chon Buri                                  5          5  ...             2         0
# Hua Hin                                    2          2  ...             0         0
# Nakhon Si Thammarat                        1          1  ...             0         0
# Nan                                        1          1  ...             0         0
# Phetchaburi                                1          1  ...             0         0
# Prachin Buri                               1          1  ...             0         0
# Samut Songkhram                            1          1  ...             0         0
# Suphan Buri                                1          1  ...             0         0
# สงขลา                                      1          1  ...             0         0
# เขาใหญ่                                    1          1  ...             0         0
#
# [13 rows x 37 columns]

# %%
searchrating = merged_table.groupby('city_name').count().sort_values(by=['weighted_average_rating'],ascending=False)
searchrating
# Out:
#                              click_timestamp  search_id  ...  pet_friendly  delivery
# city_name                                                ...
# Bangkok Metropolitan Region               83         83  ...             4        13
# Chon Buri                                  5          5  ...             2         0
# Hua Hin                                    2          2  ...             0         0
# Chaiyaphum                                 1          1  ...             0         0
# Chiang Mai                                 1          1  ...             0         0
# Nakhon Si Thammarat                        1          1  ...             0         0
# Nan                                        1          1  ...             0         0
# Phetchaburi                                1          1  ...             0         0
# Prachin Buri                               1          1  ...             0         0
# Samut Songkhram                            1          1  ...             0         0
# Suphan Buri                                1          1  ...             0         0
# สงขลา                                      1          1  ...             0         0
# เขาใหญ่                                    1          1  ...             0         0
#
# [13 rows x 37 columns]

# %%
searchrating_cut = searchrating.iloc[:1,13:14]
searchrating_cut
# Out:
#                              weighted_average_rating
# city_name
# Bangkok Metropolitan Region                       83

# %% [markdown]
# ข้อ3

# %%
data_cases
# Out:
#              No. announce_date  ... province_of_onset district_of_onset
# 0            1.0     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1            2.0     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3.0     22/1/2020  ...            นครปฐม             เมือง
# 3            4.0     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5.0     24/1/2020  ...     กรุงเทพมหานคร               NaN
# ...          ...           ...  ...               ...               ...
# 543301  543302.0     28/7/2021  ...        สุพรรณบุรี               NaN
# 543302  543303.0     28/7/2021  ...        สุพรรณบุรี               NaN
# 543303  543304.0     28/7/2021  ...        สุพรรณบุรี               NaN
# 543304  543305.0     28/7/2021  ...           ปัตตานี               NaN
# 543305       NaN           NaN  ...               NaN               NaN
#
# [543306 rows x 11 columns]

# %%
data_cases2_nomissingage
# Out:
#              No. announce_date  ... province_of_onset district_of_onset
# 0            1.0     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1            2.0     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3.0     22/1/2020  ...            นครปฐม             เมือง
# 3            4.0     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5.0     24/1/2020  ...     กรุงเทพมหานคร               NaN
# ...          ...           ...  ...               ...               ...
# 543301  543302.0     28/7/2021  ...        สุพรรณบุรี               NaN
# 543302  543303.0     28/7/2021  ...        สุพรรณบุรี               NaN
# 543303  543304.0     28/7/2021  ...        สุพรรณบุรี               NaN
# 543304  543305.0     28/7/2021  ...           ปัตตานี               NaN
# 543305       NaN           NaN  ...       ไม่มีข้อมูล               NaN
#
# [543306 rows x 11 columns]

# %%
data_cases2_nomissingage_nooutlier.groupby('risk').count()
# Out:
#                                                      No.  ...  district_of_onset
# risk                                                      ...
# 2.สัมผัสผู้ติดเชื้อ                                   10  ...                  2
# ACF รองเมือง                                          23  ...                  0
# ACF สนามกีฬาธูปะเตมีย์                                23  ...                  0
# ACF สนามกีฬาไทย-ญี่ปุ่น                              135  ...                  0
# ACF สีลม                                             108  ...                  0
# ...                                                  ...  ...                ...
# ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว      15585  ...              13546
# ไปสถานที่เสี่ยง เช่น ตลาด สถานที่ชุมชน                 1  ...                  1
# ไปสถานที่แออัด เช่น งานแฟร์ คอนเสิร์ต                863  ...                815
# ไปเที่ยวสถานบันเทิงในอุบลที่พบการระบาดของโรค Ubar      1  ...                  1
# ไปแหล่งชุมชน/สถานที่คนหนาแน่น                         17  ...                  0
#
# [135 rows x 10 columns]

# %%
risk = data_cases2_nomissingage_nooutlier.groupby('risk').count().sort_values(by=['province_of_onset'],ascending=False)
risk
# Out:
#                                                      No.  ...  district_of_onset
# risk                                                      ...
# สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้       188490  ...             174517
# การค้นหาผู้ป่วยเชิงรุกและค้นหาผู้ติดเชื้อในชุมชน   85423  ...              77167
# อยู่ระหว่างการสอบสวน                               63443  ...              40778
# อื่นๆ                                              60982  ...              48205
# ทัณฑสถาน/เรือนจำ                                   41662  ...               7822
# ...                                                  ...  ...                ...
# Cluster ระยอง วิริยะประกันภัย                          1  ...                  1
# ตรวจสุขภาพแรงงานต่างด้าว                               1  ...                  1
# สัมผัสผู้ป่วยยืนยัน (ยังไม่สามารถระบุได้)              1  ...                  1
# สัมผัสผู้ป่วยยืนยัน ภายในครอบครัว/ชุมชน/เพื่อน         1  ...                  0
# ค้นหาเชิงรุก                                           1  ...                  1
#
# [135 rows x 10 columns]

# %%
risk_cut = risk.iloc[:5,8:9]
risk_cut
# Out:
#                                                   province_of_onset
# risk
# สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้                  188490
# การค้นหาผู้ป่วยเชิงรุกและค้นหาผู้ติดเชื้อในชุมชน              85423
# อยู่ระหว่างการสอบสวน                                          63443
# อื่นๆ                                                         60982
# ทัณฑสถาน/เรือนจำ                                              41662

# %% [markdown]
# ข้อ4

# %%
data_cases2_nomissingage_nooutlier.groupby('province_of_onset').count()
# Out:
#                       No.  announce_date  ...    risk  district_of_onset
# province_of_onset                         ...
# กระบี่                779            779  ...     777                660
# กรุงเทพมหานคร      136450         136450  ...  136408             115078
# กัมพูชา                 6              6  ...       6                  2
# กาญจนบุรี            2672           2672  ...    2668               2609
# กาฬสินธิ์               3              3  ...       3                  3
# ...                   ...            ...  ...     ...                ...
# เวียงสา                 5              5  ...       5                  5
# แพร่                  480            480  ...     480                470
# แม่ฮ่องสอน             92             92  ...      92                 83
# ไม่มีข้อมูล         66915          66915  ...   66527               2196
# ไม่ระบุ                 8              8  ...       8                  7
#
# [194 rows x 10 columns]

# %%
isolation = data_cases2_nomissingage_nooutlier.groupby('province_of_onset').count().sort_values(by=['province_of_isolation'],ascending=False)
isolation
# Out:
#                       No.  announce_date  ...    risk  district_of_onset
# province_of_onset                         ...
# กรุงเทพมหานคร      136450         136450  ...  136408             115078
# ไม่มีข้อมูล         66915          66915  ...   66527               2196
# สมุทรสาคร           38625          38625  ...   38613              37295
# สมุทรปราการ         36068          36068  ...   36035              34824
# นนทบุรี             27409          27409  ...   27396              22088
# ...                   ...            ...  ...     ...                ...
# นครศรีีธรรมราช          1              1  ...       1                  1
# สุทรปราการ              1              1  ...       1                  1
# นครสววรค์               1              1  ...       1                  1
# สองแคว                  1              1  ...       1                  0
# พะยา                    1              1  ...       1                  1
#
# [194 rows x 10 columns]

# %%
isolation_cut = isolation.iloc[:10,7:8]
isolation_cut
# Out:
#                    province_of_isolation
# province_of_onset
# กรุงเทพมหานคร                     136445
# ไม่มีข้อมูล                        66538
# สมุทรสาคร                          38519
# สมุทรปราการ                        36065
# นนทบุรี                            27408
# ชลบุรี                             23726
# ปทุมธานี                           23007
# นครปฐม                             14187
# เพชรบุรี                           11333
# สงขลา                              10677

# %% [markdown]
# [PD] save

# %%
HW.to_csv('')

# %%
import

# %% [markdown]
# # [PD] การสร้างตาราง

# %% [markdown]
# ![download.png](data:image/png;base64,...)

# %%
sales = [{'account':'Jones LLC','Jan':150,'Feb':200,'Mar':140},
         {'account':'Alpha','Jan':200,'Feb':210,'Mar':215},
         {'account':'Blue Inc','Jan':50,'Feb':90,'Mar':95}]
sales
# Out:
# [{'Feb': 200, 'Jan': 150, 'Mar': 140, 'account': 'Jones LLC'},
#  {'Feb': 210, 'Jan': 200, 'Mar': 215, 'account': 'Alpha'},
#  {'Feb': 90, 'Jan': 50, 'Mar': 95, 'account': 'Blue Inc'}]
